# %% [markdown]
# #A
# BEGIN
# GENERATE RECEIPT OF PURCHASED ITEMS
# COLLECT BAG FOR PURCHASED ITEMS
# WALK TOWARDS THE SECURITY
# PRESENT RECEIPT AND PURCHASED ITEMS TO SECURITY PERSONNEL
# RECEIPT CHECKE AND VERIFIED
# WALK OUT OF STORE
# END
# ![Store Checkout Flowchart](project_1.jpg)

# %% [markdown]
# ![WeekDay Morning Routine Flowchart](project_b)

# %% [markdown]
# BEGIN
# INPUT Name 1
# INPUT Name 2
# INPUT Age 1
# INPUT Age 2
# COMPUTE temp = Name 1
# COMPUTE Name 1 = Name 2
# COMPUTE Name 2 = temp
# COMPUTE temp = Age 1
# COMPUTE Age 1 = Age 2
# COMPUTE Age 2 = temp
# DISPLAY Name 1
# DISPLAY Name 2
# DISPLAY Age 1
# DISPLAY Age 2
# END
